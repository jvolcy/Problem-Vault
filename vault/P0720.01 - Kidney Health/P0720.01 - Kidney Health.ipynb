# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; page-break-after:avoid; font-weight:700; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span>P0720.01</span><span style='color:#000; font-size:16pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:700; ' valign="baseline">&nbsp;- Kidney Health</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:700; ' valign="baseline">JVolcy</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:315.67px; height:209.37px; "><img align="right" alt="" src="images/image2.jpg" style="width:315.67px; height:209.37px; margin:10px; "/></span></p><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style="font-style:italic; ">Creatinine</span><span>&nbsp;is a waste product from the normal breakdown of muscle tissue. &nbsp;As creatinine is produced, it is filtered through the kidneys and excreted in urine. &nbsp;To measure your kidney function, your doctor first performs a blood test to measure your creatinine level, </span><span style="font-style:italic; ">Cr</span><span>&nbsp; (typical </span><span style="font-style:italic; ">Cr</span><span>&nbsp;levels are between 0.7 and 1.3). &nbsp;But that’s not enough to determine your kidney’s health. &nbsp;Good kidney function depends not only on the creatinine level, but also on age, gender and weight. &nbsp;So to assess kidney health, your doctor calculates your </span><span style="font-style:italic; ">creatinine clearance rate</span><span>, </span><span style="font-style:italic; ">CrCl</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, using the formula (called the Cockcroft-Gault equation) :</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; text-indent:36pt; '><span style="font-style:italic; ">CrCl</span><span>&nbsp;= (140 – age) × (weight, kg) × (0.85 if female) / (72 × </span><span style="font-style:italic; ">Cr</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span>Chronic Kidney Disease (</span><span style="font-style:italic; ">CKD</span><span>) is staged from the </span><span style="font-style:italic; ">CrCl</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;calculation based on the following table:</span></p><br/><a id="t.c10da4c7044edffd05c6fbc76a3cd13f93b074b0"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; background-color:#d9ead3; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='font-family:"Calibri"; font-weight:700; '>Stage of </span><span style='font-family:"Calibri"; font-weight:700; font-style:italic; '>CKD</span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:700; ' valign="baseline">&nbsp;</span></p><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:700; ' valign="baseline">(Chronic Kidney Disease)</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; background-color:#d9ead3; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:700; font-style:italic; ' valign="baseline">CrCl</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; background-color:#d9ead3; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:700; ' valign="baseline">Description</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">I</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">≥90</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">Normal kidney function</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">II</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">60-89</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">Mild decline in kidney function</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">IIIa</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">45-59</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">Mild to moderate decline in kidney function</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">IIIb</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">30-44</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">Moderate to severe decline in kidney function</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">IV</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">15-29</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">Severe decline in kidney function</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:150pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="150pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">V</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:61.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="61.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">&lt;15</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:middle; width:256.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="256.5pt"><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Calibri"; font-weight:400; ' valign="baseline">Kidney failure, usually requiring dialysis</span></p></td></tr></tbody></table><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_u72pezjumo01-0 0; "><li align="justify" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; margin-left:18pt; padding-left:0; counter-increment:lst-ctn-kix_u72pezjumo01-0} :before{content:"" counter(lst-ctn-kix_u72pezjumo01-0, decimal) ". "}; '><span>Write a function that calculates and returns the creatinine clearance rate, </span><span style="font-style:italic; ">CrCl</span><span>&nbsp;given a person’s age, weight, gender and creatinine level, </span><span style="font-style:italic; ">Cr</span><span>. &nbsp;Note that </span><span style="font-style:italic; ">CrCl</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;is always rounded to the nearest whole number, so your function should return an integer.</span></li></ol><br/><ol start="2" style="margin:0; padding:0; list-style-type:none; "><li align="justify" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; margin-left:18pt; padding-left:0; counter-increment:lst-ctn-kix_u72pezjumo01-0} :before{content:"" counter(lst-ctn-kix_u72pezjumo01-0, decimal) ". "}; '><span>Write a second function that returns the stage of Chronic Kidney Disease, </span><span style="font-style:italic; ">CKD</span><span>, given the </span><span style="font-style:italic; ">CrCl</span><span>. &nbsp;This function accepts an integer and returns a string (</span><span style='font-family:"Courier New"; font-weight:400; '>'I'</span><span>, </span><span style='font-family:"Courier New"; font-weight:400; '>'II'</span><span>, </span><span style='font-family:"Courier New"; font-weight:400; '>'IIIa'</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, etc.).</span></li></ol><br/><ol start="3" style="margin:0; padding:0; list-style-type:none; "><li align="justify" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; margin-left:18pt; padding-left:0; counter-increment:lst-ctn-kix_u72pezjumo01-0} :before{content:"" counter(lst-ctn-kix_u72pezjumo01-0, decimal) ". "}; '><span>Finally, write a program that prompts the user for his or her gender, weight, and creatinine level. &nbsp;The program should then use the two functions you wrote to calculate and printout the </span><span style="font-style:italic; ">CrCl</span><span>&nbsp;and the </span><span style="font-style:italic; ">CKD</span><span>&nbsp;stage. &nbsp;Note that the functions to calculate </span><span style="font-style:italic; ">CrCl</span><span>&nbsp;and </span><span style="font-style:italic; ">CKD</span><span>&nbsp;stage should contain no call to the </span><span style='font-family:"Courier New"; font-weight:400; '>input()</span><span>&nbsp;function and no call to the </span><span style='font-family:"Courier New"; font-weight:400; '>print()</span><span>&nbsp;function. &nbsp;All user I/O should be handled in your </span><span style='font-family:"Courier New"; font-weight:400; '>main()</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">.</span></li></ol><br/><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span>Here is a sample session:</span></p><br/><a id="t.ca462b7fa84dd727da58a6c3e0bacad4ccd672eb"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:468pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="468pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">Welcome to the CKD diagnostic program.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; '>What is your age? </span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:700; ' valign="baseline">40</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; '>What is your weight in kg? </span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:700; ' valign="baseline">70.3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; '>What is your gender (m/f): </span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:700; ' valign="baseline">f</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; '>What is your creatinine level (Cr): </span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:700; ' valign="baseline">0.94</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">Your Creatinine Clearance Rate (CrCl) is 88.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">You are at Chronic Kidney Disease stage II.</span></p></td></tr></tbody></table><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">To help with autograding, have your program prompt the user in the order shown in the sample session.</span></p><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-size:10pt; font-family:"Cambria"; font-weight:400; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='font-family:"Cambria"; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; color:#999; font-size:10pt; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
