# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span>P0115</span><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;- Easter Sunday 2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#000; font-family:"Cambria"; font-weight:700; ' valign="baseline">(Horstmann, Python, 2e)</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-right:15pt; padding-bottom:0; padding-left:-97.5pt; padding-right:0; padding-top:0; text-align:left; border-color:null; border-width:0; border-style:solid; '><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">Easter Sunday is the first Sunday after the first full moon of spring. To compute the date, you can use this algorithm, invented by the mathematician Carl Friedrich Gauss in 1800:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>1. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Let </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>y</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">&nbsp;be the year (such as 1800 or 2001).</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>2. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>y</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>19</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;and call the remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>a</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the quotient.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>3. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>y</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>100</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a quotient </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>b</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;and a remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>c</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>4. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>b</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>4</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a quotient </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>d</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;and a remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>e</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>5. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>8 * b + 13</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>25</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a quotient </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>g</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the remainder.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>6. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>19 * a + b - d - g + 15</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>30</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>h</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the quotient.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>7. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>c</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>4</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a quotient </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>j</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;and a remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>k</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>8. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>a + 11 * h</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>319</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a quotient </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>m</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the remainder.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>9. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>2 * e + 2 * j - k - h + m + 32</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>7</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>r</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the quotient.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>10. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>h - m + r + 90</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>25</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a quotient </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>n</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the remainder.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-left:46pt; margin-right:15pt; padding-bottom:0; padding-left:-15pt; padding-right:0; padding-top:0; text-align:left; text-indent:-15pt; border-color:null; border-width:0; border-style:solid; '><span style='color:#006cb7; font-family:"Arial"; font-weight:700; '>11. </span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Divide </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>h - m + r + n + 19</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;by </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>32</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;to get a remainder </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>p</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">. Ignore the quotient.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-right:15pt; padding-bottom:0; padding-left:0; padding-right:0; padding-top:0; text-align:left; border-color:null; border-width:0; border-style:solid; '><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Then Easter falls on day </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>p</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;of month </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>n</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>. For example, if </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>y</span><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>&nbsp;is </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>2001</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.25; margin-left:16pt; margin-right:15pt; padding-bottom:0; padding-top:7pt; text-align:left; '><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Courier New"; font-weight:400; ' valign="baseline">a = 6&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;h = 18&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;n = 4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.25; margin-left:16pt; margin-right:15pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Courier New"; font-weight:400; ' valign="baseline">b = 20, c = 1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;j = 0, k = 1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;p = 15</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.25; margin-left:16pt; margin-right:15pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Courier New"; font-weight:400; ' valign="baseline">d = 5, e = 0&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;m = 0</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.25; margin-left:16pt; margin-right:15pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>g = 6&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;r = 6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-right:15pt; padding-bottom:0; padding-left:0; padding-right:0; padding-top:0; text-align:left; border-color:null; border-width:0; border-style:solid; '><span style='color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; '>Write a program that prompts the user for a year, </span><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>y</span><span style='font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; color:#3c3c3c; font-family:"Times New Roman"; font-weight:400; ' valign="baseline">, &nbsp;and prints out the date of Easter Sunday for that year. &nbsp;For the above example, your program should output something like this:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.143; margin-right:15pt; padding-bottom:0; padding-left:0; padding-right:0; padding-top:0; text-align:left; border-color:null; border-width:0; border-style:solid; '><span style='color:#3c3c3c; font-family:"Courier New"; font-weight:400; '>Easter Sunday falls on 4/15 in 2001.</span></p><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
