# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span>P0005</span><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;- Schneider Ch 1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:9pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">(Schneider, Invitation to CS, 5e)</span></p><br/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>1 - </span><span>Consider the following two algorithms for shampooing your hair:</span></p><br/><a id="t.fbc97f07847eb17bb657d62104ce1976c0bce2d3"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="12pt" style="height:12pt; "><td bgcolor="#d9ead3" colspan="2" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:372pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="372pt"><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0b5394; font-family:"Bree Serif"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; Algorithm #1 for shampooing your hair</span></p><br/></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#0b5394; font-family:"Bree Serif"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0b5394; font-family:"Bree Serif"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Operation</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Wet your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Set the value of WashCount to 0</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Repeat steps 4 through 6 until the value of WashCount equals 2</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; Lather your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; Rinse your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; Add 1 to the value of WashCount</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; border-bottom-color:#fff; border-left-color:#d9ead3; border-right-color:#d9ead3; border-top-color:#d9ead3; vertical-align:top; width:45pt; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; border-bottom-color:#fff; border-left-color:#d9ead3; border-right-color:#d9ead3; border-top-color:#d9ead3; vertical-align:top; width:327pt; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Stop, you have finished shampooing your hair</span></p><br/></td></tr><tr height="0" style="height:0; "><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:0; background-color:#fff; vertical-align:top; width:45pt; border-color:#fff; border-width:1pt; border-style:solid; " valign="top" width="45pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:0; background-color:#fff; vertical-align:top; width:327pt; border-color:#fff; border-width:1pt; border-style:solid; " valign="top" width="327pt"><br/></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="2" rowspan="1" style="padding:0; background-color:#d9ead3; border-bottom-color:#d9ead3; border-left-color:#d9ead3; border-right-color:#d9ead3; border-top-color:#fff; vertical-align:top; width:372pt; border-width:1pt; border-style:solid; " valign="top" width="372pt"><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0b5394; font-family:"Bree Serif"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; Algorithm #2 for shampooing your hair</span></p><br/></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#0b5394; font-family:"Bree Serif"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0b5394; font-family:"Bree Serif"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Operation</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Wet &nbsp;your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Lather your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Rinse your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Lather your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Rinse your hair</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:45pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="45pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:0; background-color:#d9ead3; vertical-align:top; width:327pt; border-color:#d9ead3; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Stop, you have finished shampooing your hair</span></p><br/></td></tr></tbody></table><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Which do you think is a better general-purpose solution? &nbsp;Why? </span><span style='color:#000; font-size:12pt; font-style:italic; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">(Hint: what if you wanted to wash your hair 1000 times?)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Which do you think is the more efficient algorithm? &nbsp;Why? </span><span style='color:#000; font-size:12pt; font-style:italic; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">(Hint: think of a robot, not a human operator)</span></p><br/><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2 - Identify which type of algorithmic operation each one of the following steps belongs to:</span></p><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_kwm1noz0t3d8-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_kwm1noz0t3d8-0} :before{content:"" counter(lst-ctn-kix_kwm1noz0t3d8-0, lower-latin) ". "}; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Get a value for x from the user.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_kwm1noz0t3d8-0} :before{content:"" counter(lst-ctn-kix_kwm1noz0t3d8-0, lower-latin) ". "}; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Test to determine if x is positive. &nbsp;If not, tell the user that she has made a mistake.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_kwm1noz0t3d8-0} :before{content:"" counter(lst-ctn-kix_kwm1noz0t3d8-0, lower-latin) ". "}; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Take the cube root of x</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_kwm1noz0t3d8-0} :before{content:"" counter(lst-ctn-kix_kwm1noz0t3d8-0, lower-latin) ". "}; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Do steps 1.1, 1.2 and 1.3 N times.</span></li></ol><br/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>3 - One way to do multiplication is by repeated addition. &nbsp;For example, 47 ✕ 25 can be evaluated as 47+47+47+... + 47 (25 times). &nbsp;Sketch out an algorithm for multiplying two positive numbers </span><span style="font-style:italic; ">a</span><span>&nbsp;and </span><span style="font-style:italic; ">b</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;using this technique.</span></p><br/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4 - A student was asked to develop an algorithm to find and output the largest of three numerical values x, y and z that are provided as input. &nbsp;Here is what she produced:</span></p><br/><a id="t.6e9c7f171019ea0aad8095c088e833d1d3d71b7c"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:468pt; border-color:#fff; border-width:1pt; border-style:solid; " valign="top" width="468pt"><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Calibri"; font-weight:700; '>&nbsp;Input:</span><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;x, y, z</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Calibri"; font-weight:700; '>&nbsp;Algorithm:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:54pt; margin-right:18pt; text-indent:-36pt; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Check if (x &gt; y) and (x &gt; z). &nbsp;If it is, then output the value of x and stop. &nbsp;Otherwise, continue to the next line</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:54pt; margin-right:18pt; text-indent:-36pt; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Check if (y &gt; x) and (y &gt; z). &nbsp;If it is, then output the value of y and stop. &nbsp;Otherwise, continue to the next line</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:54pt; margin-right:18pt; text-indent:-36pt; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Check if (z &gt; x) and (z &gt; y). &nbsp;If it is, then output the value of z and stop.</span></p><br/></td></tr></tbody></table><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Is this a correct solution to the problem? &nbsp;Explain why or why not. &nbsp;If it is incorrect, fix the algorithm so that it is a correct solution.</span></p><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
