# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><div><br/></div><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-size:16pt; font-weight:700; ">P1102</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Chess Moves </span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-weight:700; ">Part A: The rook</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">The game of chess is played on an 8x8 checkered board as shown in the figure below. &nbsp;Each cell on the board is designated by a letter-number coordinate. &nbsp;In the figure below, the rook is shown on the board at cell E4. &nbsp;Each of the different chess pieces can travel along the board is a specific direction. &nbsp;The rook travels vertically and horizontally along rows and columns of the board. &nbsp;The possible cells the rook can travel to from its shown location in the figure are designated with a black dot. &nbsp;</span></p><br/><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:6pt; padding-top:6pt; text-align:center; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:256.50px; height:256.93px; "><img align="right" alt="" src="images/image5.png" style="width:246.50px; height:246.93px; margin:10px; "/></span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;We can represent the chessboard shown in the figure on the terminal in the following way:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4 &nbsp;- - - - R - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp;a b c d e f g h &nbsp;</span></p><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">We can represent the same board with a 2D-list of characters in the following way:</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">board = [ ['-', '-', '-', '-', '-', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', '-', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', '-', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', '-', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', 'R', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', '-', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', '-', '-', '-', '-'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">['-', '-', '-', '-', '-', '-', '-', '-'] ]</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Write a program that prompts a user for the coordinates of the rook. &nbsp;The program should then draw the chessboard on the terminal showing the location of the rook and all the possible places it can move to. &nbsp;Designate these with a '*'. &nbsp;Here is what the output of your code should be for the example above:</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4 &nbsp;* * * * R * * *</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp;a b c d e f g h &nbsp;</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Alternatively, simply print the coordinates of the rook followed by a list of the possible locations the rook can travel to. &nbsp;In that case, your output might look something like this:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; '>E4: E8, E7, E6, E3, E2, E1, A4, B4, C4, D4, F4, G4, H4</span></p><br/><hr style="page-break-before:always; display:none; "/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Part B: The bishop</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Repeat the exercise in Part A for the bishop. &nbsp;The bishop traverses the board as shown in the figure. &nbsp;Designate the bishop with a ‘B’ on the board.</span></p><br/><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:6pt; padding-top:6pt; text-align:center; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:256.50px; height:258.45px; "><img align="right" alt="" src="images/image2.png" style="width:246.50px; height:248.45px; margin:10px; "/></span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Part C: The knight</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Repeat the exercise in Part A for the knight. &nbsp;The knight traverses the board as shown in the figure. &nbsp;Designate the knight with a ‘k’ (lowercase ‘k’) on the board.</span></p><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:6pt; padding-top:6pt; text-align:center; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:259.50px; height:259.50px; "><img align="right" alt="" src="images/image1.png" style="width:249.50px; height:249.50px; margin:10px; "/></span></p><br/><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Part D: Obstructions</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">So far, we have assumed that there are no obstructions on the path of each piece. &nbsp;Repeat parts A and B above. &nbsp;This time, allow the user to enter the location of one or more pieces on the board that may obstruct the path of the rook or bishop. &nbsp;Designate these pieces with an ‘x’ on the board. &nbsp;The figure below shows that two pieces at E7 and C4 are obstructing the path of the rook at E4. &nbsp;Thus, the possible places the rook can move to is reduced.</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8 &nbsp;- - - - - - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7 &nbsp;- - - - x - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4 &nbsp;- - x * R * * *</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1 &nbsp;- - - - * - - -</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:144pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp;a b c d e f g h &nbsp;</span></p><br/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Part E: Capture the King</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">The queen is the most power piece on the board. &nbsp;The figure below shows that she can travel vertically, horizontally and diagonally across the board. &nbsp;The object of the game of chess is to capture the king. &nbsp;Write a program that prompts the user for the location of the queen, the king and other obstructing pieces (designate as ‘x’). &nbsp;The program should then determine if the queen is in position to capture the king.</span></p><br/><br/><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:6pt; padding-top:6pt; text-align:center; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:257.50px; height:258.45px; "><img align="right" alt="" src="images/image4.png" style="width:247.50px; height:248.45px; margin:10px; "/></span></p><div><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Spelman College – Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
