# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-size:16pt; font-weight:700; ">P1103</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:16pt; font-weight:700; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:16pt; font-weight:700; ' valign="baseline">Magic Squares</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:283.14px; height:227.50px; "><img align="right" alt="magic.png" src="images/image1.png" style="width:273.14px; height:217.50px; margin:10px; "/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:400; ' valign="baseline">A magic square is a 2D arrangement of numbers on a grid, with each number occurring exactly once, and such that the sum of the entries of any row, any column, or any main diagonal is the same. &nbsp;The figure on the right is a 3x3 magic square. &nbsp;The magic number for this square is 30.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>We can represent a magic square as a nested list of integers. &nbsp;Write a function named </span><span style='font-family:"Courier New"; font-weight:400; '>isMagicSquare()</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span>that accepts such a list and returns </span><span style='font-family:"Courier New"; font-weight:400; '>True</span><span>&nbsp;or </span><span style='font-family:"Courier New"; font-weight:400; '>False</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:400; ' valign="baseline">&nbsp;depending on whether the provided 2D list is or is not a magic square. &nbsp; Your function may assume that the candidate magic squares already meet the requirement that they are composed of unique numbers. &nbsp;Therefore, you simply need to verify that the columns, rows and diagonals sum to the same value.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Examine the skeleton code below. &nbsp;The main function creates six possible magic squares of different sizes (</span><span style='font-family:"Courier New"; font-weight:400; '>ms1</span><span>&nbsp;to </span><span style='font-family:"Courier New"; font-weight:400; '>ms6</span><span>). &nbsp;It calls the </span><span style='font-family:"Courier New"; font-weight:400; '>isMagicSquare()</span><span>&nbsp;function that you will create to test whether or not the six squares are magic. &nbsp; Add the </span><span style='font-family:"Courier New"; font-weight:400; '>isMagicSquare()</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:400; ' valign="baseline">&nbsp;function between the red lines as indicated in the code and verify that four of the six provided 2D lists form a magic square and two do not.</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline"># P1103.py</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline"># The isMagicSquare() function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline"># accepts a 2D list and return a boolean indicating</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline"># whether or not the 2D list forms a magic square.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline"># Assume that the provided 2D list is square (i.e.,</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline"># number of rows is equal to number of columns)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline">#-----------------------------------------------------------</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline"># </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline"># TO DO: Add your isMagicSquare() function here. &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline">#</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>#------------------------------------------------</span><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>-</span><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline">----------</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>def</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#create 6 potential magic squares</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; ms1 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;[ [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>4</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>9</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>2</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>3</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>5</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>7</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>8</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>1</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>6</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>] ] </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#3x3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; ms2 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;[ [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>4</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>9</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>2</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>8</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>1</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>6</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>3</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>5</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>7</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>] ] </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#3x3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; ms3 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;[ [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>8</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>] ] </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#1x1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; ms4 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;[ [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>52</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>11</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>85</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>28</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>88</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>25</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>51</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>12</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>21</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>82</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>18</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>55</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>15</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>58</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>22</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>81</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>] ] </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#4x4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; ms5 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;[ [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>2</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>3</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>2</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>, </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>3</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>] ] </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#2x2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; ms6 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;[ [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>23</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>6</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>19</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>2</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>15</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>4</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>12</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>25</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>8</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>16</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>10</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>18</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>1</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>14</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>22</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>11</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>24</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>7</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>20</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>3</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>], [</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>17</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>5</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>13</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>21</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>,</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>9</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>] ] </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#5x5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; isMagic1 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagicSquare(ms1) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#check magic square 1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; isMagic2 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagicSquare(ms2) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#check magic square 2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; isMagic3 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagicSquare(ms3) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#check magic square 3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; isMagic4 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagicSquare(ms4) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#check magic square 4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; isMagic5 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagicSquare(ms5) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#check magic square 5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; isMagic6 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagicSquare(ms6) &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#check magic square 6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print results for magic square 1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>if</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagic1 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>==</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#6d6d6d; '>True</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms1 is magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>else</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms1 is NOT magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print resutls for magic square 2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>if</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagic2 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>==</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='color:#6d6d6d; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">True:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms2 is magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>else</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms2 is NOT magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print results for magic square 3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>if</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagic3 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>==</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#6d6d6d; '>True</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms3 is magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>else</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms3 is NOT magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print resutls for magic square 4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>if</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagic4 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>==</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='color:#6d6d6d; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">True:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms4 is magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>else</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms4 is NOT magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print results for magic square 5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>if</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagic5 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>==</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#6d6d6d; '>True</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms5 is magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>else</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms5 is NOT magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print resutls for magic square 6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>if</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;isMagic6 </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>==</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='color:#6d6d6d; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">True:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms6 is magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>else</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'ms6 is NOT magic!'</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>main()</span></p><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">JVolcy – Spelman College – Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
