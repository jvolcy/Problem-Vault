# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="font-size:16pt; font-weight:700; ">P1101</span><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-size:16pt; font-weight:700; font-family:"Cambria"; ' valign="baseline">2D List Exercises</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:9pt; font-weight:700; ' valign="baseline">This assignment is an adaptation of the “Two </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:9pt; font-weight:700; ' valign="baseline">Dimensional Array Practice” problem set by </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:9pt; font-weight:700; ' valign="baseline">Brian Choi (schoi@cs.ucla.edu)</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Consider the following code (provided as </span><span style='font-family:"Courier New"; font-weight:400; '>P1101.py</span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">) :</span></p><br/><a id="t.d69d0e234dc16cef0cfcd6262f587cf8bd2211c9"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:468pt; border-color:#ccc; border-width:1pt; border-style:solid; " valign="top" width="468pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#skeleton program for P1101</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; size </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='color:#fb0081; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>int</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='color:#fb0081; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>input</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#00f; '>'Please enter grid size: '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">))</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#create a size X size grid of all zeros</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; A </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>=</span><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[]</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>for</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;n </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>in</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;</span><span style='color:#fb0081; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>range</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>(size): &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#will create 'size' number of rows</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; A.append([</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; color:#128b02; '>0</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>]</span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>*</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>size) &nbsp;</span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#each row will contain a list of 'size' zeros</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#---------------------------------------</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; #To do: add code between these dashed </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#f00; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; #lines that fills in the grid as indicated</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#---------------------------------------</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; print_grid(A) &nbsp; </span><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#print the grid</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; ' valign="baseline">#function that prints out a nested list as a grid</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;print_grid(grid):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>for</span><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp;row </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-size:10pt; font-weight:700; '>in</span><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;grid:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>&nbsp; &nbsp; &nbsp; &nbsp; </span><span style='color:#fb0081; font-family:"Roboto Mono"; font-size:10pt; font-weight:400; '>print</span><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">(row)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/></td></tr></tbody></table><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>The code prompts the user for an integer value, </span><span style='font-family:"Courier New"; font-weight:400; '>size</span><span>, then creates a list, </span><span style='font-family:"Courier New"; font-weight:400; '>A</span><span>, &nbsp;of length </span><span style='font-family:"Courier New"; font-weight:400; '>size</span><span>. &nbsp;Each element of </span><span style='font-family:"Courier New"; font-weight:400; '>A</span><span>&nbsp;is itself a list of </span><span style='font-family:"Courier New"; font-weight:400; '>size</span><span>&nbsp;integers. &nbsp;Printed as a grid, this 2D array of numbers looks like this for </span><span style='font-family:"Courier New"; font-weight:400; '>size = 4</span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">0 &nbsp;0 &nbsp;0 &nbsp;0</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">0 &nbsp;0 &nbsp;0 &nbsp;0</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">0 &nbsp;0 &nbsp;0 &nbsp;0</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">0 &nbsp;0 &nbsp;0 &nbsp;0</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">Run the program as provided to verify that it produces the indicated output.</span></p><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Your job in this exercise is to add code between the dashes as indicated in the program to change the contents of </span><span style='font-family:"Courier New"; font-weight:400; '>A</span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">&nbsp;to match the &nbsp;target values. &nbsp;For example, if the target output is: </span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">5 &nbsp;5 &nbsp;5 &nbsp;5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>5 &nbsp;5 &nbsp;5 &nbsp;5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">5 &nbsp;5 &nbsp;5 &nbsp;5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">5 &nbsp;5 &nbsp;5 &nbsp;5</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">your code might look like this:&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p><br/><a id="t.1c12c5ae8ffa1f6a7c022b3e75d37bdc76a116c6"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-17.2pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:207.8pt; border-color:#999; border-width:1pt; border-style:solid; " valign="top" width="207.8pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">row_num = 0</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">for row in A:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; col_num = 0</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; for item in row:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; A[row_num][col_num] = 5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; col_num += 1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; row_num += 1</span></p><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-color:#fff; border-left-color:#999; border-right-color:#999; border-top-color:#fff; vertical-align:top; width:27.8pt; border-width:1pt; border-style:solid; " valign="top" width="27.8pt"><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-style:italic; text-decoration:none; vertical-align:baseline; font-size:14pt; font-weight:700; ' valign="baseline">Or</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:258pt; border-color:#999; border-width:1pt; border-style:solid; " valign="top" width="258pt"><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">for row_num in range(size):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; for col_num in range(size):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; A[row_num][col_num] = 5</span></p><br/></td></tr></tbody></table><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Y</span><span>our code must work with any positive </span><span style='font-family:"Courier New"; font-weight:400; '>size</span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">&nbsp;value entered by the user. &nbsp; In each case, name your program as indicated.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:14pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Part A: Base Problem Set</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#00f; font-style:italic; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">P1101a1.py &nbsp; &nbsp; &nbsp; &nbsp;P1101a2.py &nbsp; &nbsp; &nbsp;P1101a3.py &nbsp; &nbsp; &nbsp; P1101a4.py</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp;0 &nbsp;1 &nbsp;2 &nbsp;3 &nbsp;4 &nbsp; &nbsp;0 &nbsp;0 &nbsp;0 &nbsp;0 &nbsp;0 &nbsp; &nbsp;5 &nbsp;4 &nbsp;3 &nbsp;2 &nbsp;1 &nbsp; 21 22 23 24 25 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp;0 &nbsp;1 &nbsp;2 &nbsp;3 &nbsp;4 &nbsp; &nbsp;1 &nbsp;1 &nbsp;1 &nbsp;1 &nbsp;1 &nbsp; 10 &nbsp;9 &nbsp;8 &nbsp;7 &nbsp;6 &nbsp; 16 17 18 19 20 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp;0 &nbsp;1 &nbsp;2 &nbsp;3 &nbsp;4 &nbsp; &nbsp;2 &nbsp;2 &nbsp;2 &nbsp;2 &nbsp;2 &nbsp; 15 14 13 12 11 &nbsp; 11 12 13 14 15 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbs
span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp; 5 &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>9</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;14 </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>19</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp; </span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp; 3 &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>2 &nbsp;2 &nbsp;2</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp; 3 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>17 18</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;10 11 12 &nbsp; </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>14 15</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;11 12 13 &nbsp; &nbsp;4 &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>8</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;13 </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>18</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;22 &nbsp; &nbsp;3 &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>2</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp; 1 &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>2</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp; 3 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>19 20 21</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;13 14 &nbsp; </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>18 19 20</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;16 17 &nbsp; &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>7</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;12 </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>17</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;21 </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>24</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp; &nbsp; 3 &nbsp;</span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>2 &nbsp;2 &nbsp;2</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp; 3 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>22 23 24 25</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;15 &nbsp; </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>22 23 24 25</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;21 &nbsp; 11 </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>16</span><span style='font-family:"Courier New"; font-weight:400; font-size:11pt; '>&nbsp;20 </span><span bgcolor="#c0c0c0" style='background-color:#c0c0c0; font-family:"Courier New"; font-size:11pt; font-weight:400; '>23</span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp;25 &nbsp; &nbsp;3 &nbsp;3 &nbsp;3 &nbsp;3 &nbsp;3 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-size:11pt; font-weight:700; '>&nbsp;Problem 9 &nbsp; &nbsp; &nbsp; &nbsp;Problem 10 &nbsp; &nbsp; &nbsp; Problem 11 &nbsp; &nbsp; &nbsp; Problem 12*</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">*For problem 12, assume that size is an odd number</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-size:14pt; font-weight:700; ">Part C: Even More Challenging Problems</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#00f; font-style:italic; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">P1101c.py</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; 1 &nbsp;2 &nbsp;3 &nbsp;4 &nbsp;5 &nbsp;6 &nbsp;7 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; 1 &nbsp;2 &nbsp;3 &nbsp;4 &nbsp;5 &nbsp;6 &nbsp; 24 25 26 27 28 29 &nbsp;8 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">&nbsp;1 &nbsp;2 &nbsp;3 &nbsp;4 &nbsp;5 &nbsp; 20 21 22 23 24 &nbsp;7 &nbsp; 23 40 41 42 43 30 &nbsp;9 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">16 17 18 19 &nbsp;6 &nbsp; 19 32 33 34 25 &nbsp;8 &nbsp; 22 39 48 49 44 31 10 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">15 24 25 20 &nbsp;7 &nbsp; 18 31 36 35 26 &nbsp;9 &nbsp; 21 38 47 46 45 32 11 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">14 23 22 21 &nbsp;8 &nbsp; 17 30 29 28 27 10 &nbsp; 20 37 36 35 34 33 12 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; font-size:11pt; ' valign="baseline">13 12 11 10 &nbsp;9 &nbsp; 16 15 14 13 12 11 &nbsp; 19 18 17 16 15 14 13 </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-size:11pt; font-weight:700; '>&nbsp;SIZE = 5 &nbsp; &nbsp; &nbsp; &nbsp; SIZE = 6 &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;SIZE = 7 </span></p><br/><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">Spelman College – Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
