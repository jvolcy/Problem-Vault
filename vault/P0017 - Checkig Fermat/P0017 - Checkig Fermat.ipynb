# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span>P0017</span><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;- Checking Fermat</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:9pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">(A. Downey, Think Python, 2e)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Fermat’s Last Theorem states that there are no integers </span><span style="font-style:italic; ">a, b</span><span>&nbsp;and </span><span style="font-style:italic; ">c</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;such that</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; text-indent:36pt; '><span style="font-style:italic; ">a</span><span style="vertical-align:super; font-style:italic; " valign="super">n</span><span style="font-style:italic; ">&nbsp;+ b</span><span style="vertical-align:super; font-style:italic; " valign="super">n</span><span style="font-style:italic; ">&nbsp;= c</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:400; text-decoration:none; vertical-align:super; font-style:italic; ' valign="super">n</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>for values of </span><span style="font-style:italic; ">n</span><span>&nbsp;greater than 2. &nbsp;Write an algorithm that accepts four integers </span><span style="font-style:italic; ">A, B, C</span><span>&nbsp;and </span><span style="font-style:italic; ">N (N &gt; 2)</span><span>&nbsp;and checks this theorem for </span><span style="font-style:italic; ">every</span><span>&nbsp;combination of values in the range </span><span style="font-style:italic; ">a=1 to A, b = 1 to B, c = 1 to C</span><span>&nbsp;and </span><span style="font-style:italic; ">n = 3 to N</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">. &nbsp;For example, if the user enters A=2, B=3, C=2 and N=4, your algorithm will have to check the following cases:</span></p><br/><a id="t.9ae74f1c72f7776ae4d22c493ea409e3d696e3d0"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:auto; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:400; text-decoration:none; vertical-align:baseline; font-style:italic; ' valign="baseline">n</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:400; text-decoration:none; vertical-align:baseline; font-style:italic; ' valign="baseline">a</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:400; text-decoration:none; vertical-align:baseline; font-style:italic; ' valign="baseline">b</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:400; text-decoration:none; vertical-align:baseline; font-style:italic; ' valign="baseline">c</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:top; width:36pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="36pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td></tr></tbody></table><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>If your algorithm finds a case where the theorem fails, print “Holy smokes, Fermat was wrong!” and stop. &nbsp;Otherwise simply print “Nope, that combination doesn’t work”.</span></p><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='font-family:"Cambria"; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; color:#999; font-size:10pt; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
