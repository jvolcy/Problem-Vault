# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">P0711.01</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Functions &amp; Local Variables</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">JVolcy</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">For each program, identify the order of execution. &nbsp;Then, predict the output.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 1</span></p><br/><a id="t.54ddb858f27c9f577a4dd97016b6d48d1021dc36"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:90.9pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="90.9pt"><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='font-family:"Roboto Mono"; font-weight:400; '>_________</span></p></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:405.9pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="405.9pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#Program that demonstrates use of local variables. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>"Who's funky?"</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'Bye'</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the funk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk(funk_level):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my funk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#increment the funk level!</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>+=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Call the main function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 2</span></p><br/><br/><a id="t.7bfc6f6bb3f2c9fc96e2c2fff1092ed4d0f94d1d"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#Program that demonstrates use of local variables. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>"Who's funky?"</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level</span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>3</span><span style='font-family:"Roboto Mono"; font-weight:400; '>, multiplier</span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>+</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>1</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'Bye'</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the funk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my funk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Call the main function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/><br/></td></tr></tbody></table><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 3</span></p><br/><br/><a id="t.a867dd87b9403bc070bafc32e4fb050c2a268a69"></a><a id="t.2"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#Program that demonstrates use of local variables. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>"Who's funky?"</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'multiplier = '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'Bye'</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the funk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>+=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my funk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Call the main function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 4</span></p><br/><br/><br/><a id="t.224f9af5ffd1b230881694dcde5806118638c561"></a><a id="t.3"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#Program that demonstrates use of local variables. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>"Who's funky?"</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level</span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>+</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>1</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'Bye'</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the funk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>+=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my funk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Call the main function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 5</span></p><br/><br/><a id="t.5e5c1838258329f8ec025f13fb181ff6e5fa6230"></a><a id="t.4"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#Program that demonstrates use of local variables. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>"Who's funky?"</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'Bye'</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the funk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;spunk(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>2</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my funk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the spunk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;spunk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;spunk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;spunk_level</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my spunk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, spunk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Call the main function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/></td></tr></tbody></table><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 6</span></p><br/><br/><a id="t.8b02e229a1ac7a8c3f29d9c82c5cc84eed4c0ad0"></a><a id="t.5"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '>#Program that demonstrates use of local variables. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;spunk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;multiplier </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>"Who's funky?"</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(funk_level, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;spunk(spunk_level, </span><span style='font-family:"Roboto Mono"; font-weight:400; color:#128b02; '>2</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;funk(spunk_level, multiplier)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'Bye'</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the funk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;spunk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;funk_level</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my funk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, funk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Definition of the spunk function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>def</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;spunk(level, multiplier):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;spunk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>*</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;multiplier</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;funk_level </span><span style='color:#0a5287; font-family:"Roboto Mono"; font-weight:700; '>=</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;spunk_level</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Roboto Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#fb0081; '>print</span><span style='font-family:"Roboto Mono"; font-weight:400; '>(</span><span style='font-family:"Roboto Mono"; font-weight:400; color:#00f; '>'my spunk level is '</span><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, spunk_level)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#0f7201; font-family:"Roboto Mono"; font-weight:400; '># Call the main function. </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:6pt; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p></td></tr></tbody></table><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
