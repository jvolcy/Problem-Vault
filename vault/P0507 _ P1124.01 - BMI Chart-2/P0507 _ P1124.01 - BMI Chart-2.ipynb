# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span>P0507 / P1124.01</span><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;- &nbsp;BMI Chart </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:9pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">JVolcy</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:14pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">P0507</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Consider the Body Mass Index (BMI) table shown below. &nbsp;BMI is calculated as</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:108pt; text-indent:36pt; '><img src="images/image1.png"/></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style="overflow:hidden; display:inline-block; margin:0.00px 0.00px; border:0.00px solid #000000; width:597.50px; height:570.74px; "><img align="right" alt="bmi2.xlsx.png" src="images/image3.png" style="width:759.01px; height:982.82px; margin:10px; "/></span></p><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">BMI is used to classify adults according to the following table:</span></p><br/><br/><a id="t.40e3bb48f737f3e2aee1fb6d21080c4fa0566294"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:105.8pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="105.8pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">BMI Range</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:362.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="362.2pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Classification</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:105.8pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="105.8pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">BMI &lt; 18.5</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:362.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="362.2pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Underweight (shown in yellow on the BMI chart)</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:105.8pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="105.8pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">18.5 &lt;= BMI &lt; 25</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:362.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="362.2pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Normal weight (shown in green on the BMI chart)</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:105.8pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="105.8pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">25 &lt;= BMI &lt; 30</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:362.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="362.2pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Overweight (shown in orange on the BMI chart)</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:105.8pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="105.8pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">30 &lt;= BMI</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:362.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="362.2pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Calibri"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Extremely Overweight (shown in pink on the BMI chart)</span></p></td></tr></tbody></table><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Given the BMI formula and the BMI classifications, your job is to write a program that generates a BMI chart similar to the one shown. &nbsp;Rather than showing the actual BMI values, your chart will show a single letter, U, N, O or X corresponding to BMI classifications Underweight, Normal weight, Overweight and Extremely Overweight. &nbsp;Here is what your chart might look like:</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">BMI Classification</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Height (inches) vs Weight (pounds)</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp;|100|110|120|130|140|150|160|170|180|190|200|210|220|230|240|250|260</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; font-size:10pt; '>-----------------------------------------------------------------------<br/>54 | N | O | O | X | X | X | X | X | X | X | X | X | X | X | X | X | X<br/>56 | N | N | O | O | X | X | X | X | X | X | X | X | X | X | X | X | X<br/>58 | N | N | O | O | O | X | X | X | X | X | X | X | X | X | X | X | X<br/>60 | N | N | N | O | O | O | X | X | X | X | X | X | X | X | X | X | X<br/>62 | U | N | N | N | O | O | O | X | X | X | X | X | X | X | X | X | X<br/>64 | U | N | N | N | N | O | O | O | X | X | X | X | X | X | X | X | X<br/>66 | U | U | N | N | N | N | O | O | O | X | X | X | X | X | X | X | X<br/>68 | U | U | U | N | N | N | N | O | O | O | X | X | X | X | X | X | X<br/>70 | U | U | U | N | N | N | N | N | O | O | O | X | X | X | X | X | X<br/>72 | U | U | U | U | N | N | N | N | N | O | O | O | O | X | X | X | X<br/>74 | U | U | U | U | U | N | N | N | N | N | O | O | O | O | X | X | X<br/>76 | U | U | U | U | U | U | N | N | N | N | N | O | O | O | O | X | X<br/>78 | U | U | U | U | U | U | U | N | N | N | N | N | O | O | O | O | X<br/>80 | U | U | U | U | U | U | U | N | N | N | N | N | N | O | O | O | O<br/>82 | U | U | U | U | U | U | U | U | N | N | N | N | N | N | O | O | O<br/>84 | U | U | U | U | U | U | U | U | U | N | N | N | N | N | N | N | O<br/></span></p><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:14pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">P1124.01</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Review the details of problem P0507. &nbsp;This time, rather than outputting the BMI table to the screen, we will store it in a 2D list. &nbsp;Begin &nbsp;with the skeleton code found </span><span style="-webkit-text-decoration-skip:none; color:#15c; text-decoration:underline; text-decoration-skip-ink:none; "><a href="https://www.google.com/url?q=https://drive.google.com/open?id%3D1iMOhx_b8V51mytjj9YA-ahNVDHgGNgmI&amp;sa=D&amp;ust=1577371725784000" style="color:inherit; text-decoration:inherit; ">here</a></span><span>. &nbsp;This code defines a 2D list named </span><span style='font-family:"Courier New"; font-weight:400; '>bmi</span><span>. &nbsp;When the code is run, the output shows that the initial contents of </span><span style='font-family:"Courier New"; font-weight:400; '>bmi</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;is</span></p><br/><a id="t.9b45e8871c8e61e2ae3e4851ab022c6661ef8bad"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-21.8pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:505.5pt; background-color:#cfe2f3; border-color:#fff; border-width:1pt; border-style:solid; " valign="top" width="505.5pt"><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">[['', 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220, 230, 240, 250, 260]</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[54, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[56, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[58, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[60, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[62, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[64, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[66, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[68, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[70, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[72, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[74, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[76, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[78, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[80, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[82, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[84, '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']]</span></p><br/></td></tr></tbody></table><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>The </span><span style='font-family:"Courier New"; font-weight:400; '>'?'</span><span>s indicate a place holders for a value of </span><span style='font-family:"Courier New"; font-weight:400; '>'U', 'N', 'O' </span><span>or </span><span style='font-family:"Courier New"; font-weight:400; '>'X'</span><span>&nbsp;as described in P0507. &nbsp;Your task is to use the BMI formula from problem P0507 to replace every </span><span style='font-family:"Courier New"; font-weight:400; '>'?' </span><span>so that the final contents of the </span><span style='font-family:"Courier New"; font-weight:400; '>bmi</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;list to look like this:</span></p><br/><a id="t.9b41b2937bd697c50f10de988ec382ae00d6da12"></a><a id="t.2"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-22.5pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:506.2pt; background-color:#cfe2f3; border-color:#fff; border-width:1pt; border-style:solid; " valign="top" width="506.2pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">[['', 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210, 220, 230, 240, 250, 260]</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[54, 'N', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[56, 'N', 'N', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[58, 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[60, 'N', 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[62, 'U', 'N', 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[64, 'U', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[66, 'U', 'U', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[68, 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[70, 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'X', 'X', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[72, 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'O', 'X', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[74, 'U', 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'O', 'X', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[76, 'U', 'U', 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'O', 'X', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[78, 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'O', 'X']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[80, 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O', 'O']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[82, 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'N', 'O', 'O', 'O']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:9pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;[84, 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'O']]</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">A few tips and observations:</span></p><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_tueh6o2mroo6-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:36pt; padding-left:0; counter-increment:lst-ctn-kix_tueh6o2mroo6-0} :before{content:"" counter(lst-ctn-kix_tueh6o2mroo6-0, decimal) ". "}; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">You should only write code between the lines where indicated in the skeleton file.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:36pt; padding-left:0; counter-increment:lst-ctn-kix_tueh6o2mroo6-0} :before{content:"" counter(lst-ctn-kix_tueh6o2mroo6-0, decimal) ". "}; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Element [0][0] of the bmi array is set to an empty string. &nbsp;This is an unused element.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:36pt; padding-left:0; counter-increment:lst-ctn-kix_tueh6o2mroo6-0} :before{content:"" counter(lst-ctn-kix_tueh6o2mroo6-0, decimal) ". "}; '><span>Column 0 of </span><span style='font-family:"Courier New"; font-weight:400; '>bmi</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;contains height information. &nbsp;Use the information in this column to calculate the bmi values, but do not modify this column.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:36pt; padding-left:0; counter-increment:lst-ctn-kix_tueh6o2mroo6-0} :before{content:"" counter(lst-ctn-kix_tueh6o2mroo6-0, decimal) ". "}; '><span>Row 0 of </span><span style='font-family:"Courier New"; font-weight:400; '>bmi</span><span>&nbsp;contains weight information. &nbsp;Use the information in this row to calculate the bmi values, but do not modify this row.</span></li></ol><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
