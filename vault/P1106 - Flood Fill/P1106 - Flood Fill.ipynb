# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span>P1106</span><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;- Flood Fill</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:700; ' valign="baseline">JVolcy</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">Computer images are stored as a matrix of pixels each assigned a specific color. &nbsp;Figure 1 below is a 16x16 image of the famous video game character, Mario. &nbsp;The colors of the pixels in the image are represented by letters according to the following table:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">R - Red</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">W - White</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K - Black</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">B - Brown</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">Y - Yellow</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">G - Green</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">L - Blue</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">O - Orange</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">P - Purple</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">A - Gray</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">N - Pink</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">T - Tan</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">Each pixel in the image can be identified by its (x, y) coordinate with the origin in the upper left corner as shown.</span></p><br/><a id="t.d72554cd705416a5fca5154cc61981d644785a66"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#fff; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><br/></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">0</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">10</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">11</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">12</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">13</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">14</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">15</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">0</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">10</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">11</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">12</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">13</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">14</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">15</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr></tbody></table><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-size:11pt; font-weight:700; ">Figure 1. </span><span style='color:#000; font-size:11pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">&nbsp;16 x 16 image of Mario.</span></p><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">Flood filling is a common operation in image processing. &nbsp;Given a pixel (x, y), flood filling means changing the color of the target pixel and all pixels in the same region. &nbsp;Pixels are said to be in the same region if they are of the same color and share an edge. &nbsp;For example, if we flood fill Figure 1 with green starting with pixel (1,6), the result is</span></p><br/><br/><br/><a id="t.309614aa768489536148e232772085016a365177"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#fff; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><br/></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">0</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">10</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">11</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">12</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">13</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">14</span></p></td><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#fff; border-right-color:#fff; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">15</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">0</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; border-bottom-color:#ff0; border-left-color:#000; border-right-color:#000; border-top-color:#000; vertical-align:middle; width:18pt; background-color:#93c47d; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#000; border-right-color:#ff0; border-top-color:#000; vertical-align:middle; width:18pt; background-color:#93c47d; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#ff0; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#ff0; border-right-color:#000; border-top-color:#000; vertical-align:middle; width:18pt; background-color:#93c47d; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; border-bottom-color:#000; border-left-color:#000; border-right-color:#000; border-top-color:#ff0; vertical-align:middle; width:18pt; background-color:#93c47d; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">10</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#b45f06" colspan="1" rowspan="1" style="padding:0; background-color:#b45f06; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">11</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">12</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td bgcolor="#f6b26b" colspan="1" rowspan="1" style="padding:0; background-color:#f6b26b; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">13</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td bgcolor="#ff0000" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#f00; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">14</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr><tr height="18pt" style="height:18pt; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-color:#fff; border-left-color:#fff; border-right-color:#000; border-top-color:#fff; vertical-align:middle; width:18pt; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#00f; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">15</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#93c47d" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#93c47d; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td bgcolor="#434343" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; background-color:#434343; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:18pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="18pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td></tr></tbody></table><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-size:11pt; font-weight:700; ">Figure 2. </span><span style='color:#000; font-size:11pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">&nbsp;Image of Mario with a &nbsp;green flood filled region beginning at (1, 6).</span></p><br/><br/><hr style="page-break-before:always; display:none; "/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">The image in Figure 1 can be represented with the following nested Python lists:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">mario = [</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'W', 'W', 'R', 'R', 'R', 'R', 'R', 'W', 'W', 'W', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'W', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'W', 'K', 'K', 'K', 'T', 'T', 'K', 'T', 'W', 'W', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'K', 'T', 'K', 'T', 'T', 'T', 'K', 'T', 'T', 'T', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'K', 'T', 'K', 'K', 'T', 'T', 'T', 'K', 'T', 'T', 'T', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'K', 'K', 'T', 'T', 'T', 'T', 'K', 'K', 'K', 'K', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'W', 'W', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'W', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'W', 'B', 'B', 'R', 'B', 'B', 'B', 'W', 'W', 'W', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'B', 'B', 'B', 'R', 'B', 'B', 'R', 'B', 'B', 'B', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'B', 'B', 'B', 'B', 'R', 'R', 'R', 'R', 'B', 'B', 'B', 'B', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'T', 'T', 'B', 'R', 'T', 'R', 'R', 'T', 'R', 'B', 'T', 'T', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'T', 'T', 'T', 'R', 'R', 'R', 'R', 'R', 'R', 'T', 'T', 'T', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'T', 'T', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'T', 'T', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'W', 'R', 'R', 'R', 'W', 'W', 'R', 'R', 'R', 'W', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'W', 'K', 'K', 'K', 'W', 'W', 'W', 'W', 'K', 'K', 'K', 'W', 'W', 'W'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-size:9pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-weight:400; ' valign="baseline">['W', 'W', 'K', 'K', 'K', 'K', 'W', 'W', 'W', 'W', 'K', 'K', 'K', 'K', 'W', 'W'] ]</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Beginning with this nested list, write a program that prompts the user for a color code (</span><span style='font-family:"Courier New"; font-weight:400; '>R, K, B, G,</span><span style='color:#000; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">&nbsp;etc.) and a pixel coordinate. &nbsp;The program should then perform a fill operation on the image before printing the resulting image to the screen. &nbsp;</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>You may begin with the skeleton code found </span><span style="-webkit-text-decoration-skip:none; color:#15c; text-decoration:underline; text-decoration-skip-ink:none; "><a href="https://www.google.com/url?q=https://drive.google.com/open?id%3D0B_r-sqlBQ5V3ZWh2MVpNX1BiRTA&amp;sa=D&amp;ust=1577371759422000" style="color:inherit; text-decoration:inherit; ">here</a></span><span>.</span></p><br/><br/><br/><br/><br/><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-size:10pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-weight:400; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
