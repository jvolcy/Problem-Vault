# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo (no bg).png" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span>P0032</span><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;- Algorithm Classification</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:9pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">JVolcy</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">For this exercise, we will consider an algorithm to be a “sequential algorithm” if it contains no conditional and no iterative elements. &nbsp;We will consider an algorithm to be a “conditional algorithm” if it contain one or more conditional elements, but no iterative elements. &nbsp;If an algorithm contains a single iterative element, we will consider it to be an “iterative algorithm”. &nbsp;We can characterize the types of algorithms as follows:</span></p><br/><a id="t.613441f6be08a377e707383a519dbd78b3853a48"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:141pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="141pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Type of algorithm</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:327pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Characteristics</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#f3f3f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#f3f3f3; vertical-align:top; width:141pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="141pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Sequential Algorithm</span></p></td><td bgcolor="#f3f3f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#f3f3f3; vertical-align:top; width:327pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Every line of code is executed exactly once</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#f3f3f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#f3f3f3; vertical-align:top; width:141pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="141pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Conditional Algorithm</span></p></td><td bgcolor="#f3f3f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#f3f3f3; vertical-align:top; width:327pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Not every line of code may be executed. &nbsp;No line of code is ever executed more than once.</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#f3f3f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#f3f3f3; vertical-align:top; width:141pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="141pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Iterative Algorithm</span></p></td><td bgcolor="#f3f3f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#f3f3f3; vertical-align:top; width:327pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="327pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">At least one line of code may be executed more than once</span></p></td></tr></tbody></table><br/><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:center; '><span style="overflow:hidden; display:inline-block; margin:0.00px 0.00px; border:0.00px solid #000000; width:472.00px; height:184.42px; "><img align="right" alt="" src="images/image2.png" style="width:462.00px; height:174.42px; margin:10px; "/></span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style="font-size:10pt; font-style:italic; ">Note that in actuality, an algorithms is rarely purely sequential and never purely conditional or purely iterative. &nbsp;Rather, most algorithms contain sections of sequential, conditional and iterative code.</span></p><br/><hr/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">For each algorithm below, identify whether the algorithm is best described as sequential, conditional or iterative based on the definition provided above.</span></p><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">a) Brushing Your Teeth</span></p><br/><a id="t.21d31d91038f5e89fb20a072c1dedbcab78080a4"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#d9ead3; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_5063lices00-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; margin-right:-2.2pt; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Unscrew the cap from the tube of toothpaste</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Squeeze the tube of paste from the bottom of the tube, forcing the contents forward toward the opened end</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Dispense approximately a 1/2" length of toothpaste on a toothbrush</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Recap the tube of toothpaste</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Gently move the brush back and forth in short (tooth-wide) strokes across your teeth</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Brush the outer surfaces, the inner surfaces, and the chewing surfaces of the teeth for approximately 1 minute each</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_5063lices00-0} :before{content:"" counter(lst-ctn-kix_5063lices00-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Rinse out the toothpaste from your mouth with clean water, making sure not to swallow any of the paste</span></li></ol><br/></td></tr></tbody></table><br/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Arial"; font-weight:700; '>b) Flu Test</span></p><br/><a id="t.a5054a60f7bb4aee5560a898a2ff14d5efbc54f9"></a><a id="t.2"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#fce5cd" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fce5cd; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_8bj2xecivbki-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-0} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Administer a standard flu test</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-0} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">if the flu test is positive</span></li></ol><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_8bj2xecivbki-1 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-1} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) "." counter(lst-ctn-kix_8bj2xecivbki-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">begin antiviral treatment</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-1} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) "." counter(lst-ctn-kix_8bj2xecivbki-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">stop</span></li></ol><ol start="3" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-0} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">if the patient’s symptoms appeared more than 4 days ago</span></li></ol><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_8bj2xecivbki-1 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-1} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) "." counter(lst-ctn-kix_8bj2xecivbki-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">the test is inconclusive</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-1} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) "." counter(lst-ctn-kix_8bj2xecivbki-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">send the patient out for a more sophisticated flu test</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-1} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) "." counter(lst-ctn-kix_8bj2xecivbki-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">stop</span></li></ol><ol start="4" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-0} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">The patient does not have the flu</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_8bj2xecivbki-0} :before{content:"" counter(lst-ctn-kix_8bj2xecivbki-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">stop</span></li></ol><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">c) Checking Your Engine Oil Level<br/></span></p><a id="t.ab47c81e336caa4e1093aefc53cc9e4f0220a88e"></a><a id="t.3"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#d9ead3; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_azem9hotfw58-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Locate the engine oil dipstick</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Pull out the dipstick and wipe it off with a clean, lint-free rag.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Insert the stick back into the pipe.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Pull the dipstick out again and look at the film of oil on the end of the stick.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">If the oil line is at or below the ‘Add’ line</span></li></ol><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_azem9hotfw58-1 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-1} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) "." counter(lst-ctn-kix_azem9hotfw58-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Remove the oil fill cap at the top of the engine block and Add 1 quart of oil.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-1} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) "." counter(lst-ctn-kix_azem9hotfw58-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Go to step 3.</span></li></ol><ol start="6" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Insert the stick back into the pipe.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_azem9hotfw58-0} :before{content:"" counter(lst-ctn-kix_azem9hotfw58-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Replace the fill cap if it was removed.</span></li></ol><br/></td></tr></tbody></table><br/><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">d) Changing a Diaper<br/></span></p><a id="t.7866488e1eaeb919913ac5483b1507275b4349d1"></a><a id="t.4"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#fce5cd" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fce5cd; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_9bjupjtebk5n-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Lay your baby on his or her back. Remove any clothing that inhibits access to the diaper. </span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Pull up on the stick tabs to remove the soiled diaper. </span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Lift your baby up gently so you can scoot the diaper out from under him or her.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Use wipes to clean your baby's diaper region. Always wipe from front to back to avoid infection, especially for girls.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">If the area is red or inflamed, soothe it with diaper ointment.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Wait for your baby's skin to dry before putting on a fresh diaper.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Take a fresh diaper and place it under your baby. Bring the front part up on your baby's stomach and fasten the tabs to secure the diaper on his waist.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_9bjupjtebk5n-0} :before{content:"" counter(lst-ctn-kix_9bjupjtebk5n-0, decimal) ". "}; '><span style='color:#222; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Replace any clothing over the new diaper.</span></li></ol><br/></td></tr></tbody></table><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">e) How to Tie Dye</span></p><br/><a id="t.363f5ffc66707e1c7457e0297f1d78ae406593e6"></a><a id="t.5"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#d9ead3; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_ngqta8x1hfdy-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_ngqta8x1hfdy-0} :before{content:"" counter(lst-ctn-kix_ngqta8x1hfdy-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Gather the following items</span></li></ol><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Tie dye kit</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">White 100% cotton T-shirt</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Several rubber bands</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Water</span></p><ol start="2" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_ngqta8x1hfdy-0} :before{content:"" counter(lst-ctn-kix_ngqta8x1hfdy-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Fold and twist your shirt according to your chosen tie-dye pattern</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_ngqta8x1hfdy-0} :before{content:"" counter(lst-ctn-kix_ngqta8x1hfdy-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Secure the shirt in the twisted/folded position using as many rubber bands as necessary</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_ngqta8x1hfdy-0} :before{content:"" counter(lst-ctn-kix_ngqta8x1hfdy-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Mix your dyes by adding water and shaking the dye bottles until all of the dye is mixed</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_ngqta8x1hfdy-0} :before{content:"" counter(lst-ctn-kix_ngqta8x1hfdy-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Squeeze dye onto different sections of your bound fabric to your liking. You might need to rotate and/or flip your fabric as you are applying dye to make sure you cover all sections.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_ngqta8x1hfdy-0} :before{content:"" counter(lst-ctn-kix_ngqta8x1hfdy-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Place the dyed fabric in plastic ziplock bag to keep it damp while the dye sets. Let it set for 6 to 8 hours or longer for brightest colors.</span></li></ol><br/></td></tr></tbody></table><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">f) Washing at the Laundromat<br/></span></p><a id="t.2b630ca727286848e982b5a4c6b264821c1870ec"></a><a id="t.6"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#fce5cd" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fce5cd; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_3nbh6sdey6oe-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Sort the laundry into dark colors and light colors</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Find an available washer</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Add ½ cup of laundry detergent to the empty washer</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Place the dark colors in the washer</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Place 3 quarters into the machine coin slots</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Press the ‘Start’ button</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Find another available washer</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Add ½ cup of laundry detergent to the empty washer</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Place the light colors in the washer</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Place 3 quarters into the machine coin slots</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Press the ‘Start’ button</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_3nbh6sdey6oe-0} :before{content:"" counter(lst-ctn-kix_3nbh6sdey6oe-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Wait for both machine to complete washing</span></li></ol><br/></td></tr></tbody></table><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">g) Faxing a Document<br/></span></p><a id="t.9a38ffa3e91a7b1ccbf03f1c05671331cfbfbe9d"></a><a id="t.7"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#d9ead3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#d9ead3; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_z60arxlvxb7a-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Pick up the handset and verify that you have a dial tone.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Hang up the handset</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Place the document face down on the platen glass</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Dial in the destination number</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Press ‘Start’</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">If you get a busy signal</span></li></ol><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_z60arxlvxb7a-1 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-1} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) "." counter(lst-ctn-kix_z60arxlvxb7a-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Wait 5 minutes</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-1} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) "." counter(lst-ctn-kix_z60arxlvxb7a-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Go to step 4</span></li></ol><ol start="7" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Wait for the transmission report</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">If the transmission is not ok</span></li></ol><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_z60arxlvxb7a-1 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-1} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) "." counter(lst-ctn-kix_z60arxlvxb7a-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Address the issue on the transmission report</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:72pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-1} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) "." counter(lst-ctn-kix_z60arxlvxb7a-1, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Go to step 4</span></li></ol><ol start="9" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_z60arxlvxb7a-0} :before{content:"" counter(lst-ctn-kix_z60arxlvxb7a-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Remove your document from the platen glass</span></li></ol><br/></td></tr></tbody></table><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">h) Scrambled Eggs<br/></span></p><a id="t.5e23e84676240e5177aa2c04fb2c85a84bea182b"></a><a id="t.8"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#fce5cd" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fce5cd; vertical-align:top; width:467.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="467.2pt"><br/><ol start="1" style="margin:0; padding:0; list-style-type:none; counter-reset:lst-ctn-kix_guu3akn5m1j8-0 0; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_guu3akn5m1j8-0} :before{content:"" counter(lst-ctn-kix_guu3akn5m1j8-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Gather the following ingredients</span></li></ol><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4 eggs</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">¼ cup milk</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Salt and pepper</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.15; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2 tsp. butter</span></p><ol start="2" style="margin:0; padding:0; list-style-type:none; "><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_guu3akn5m1j8-0} :before{content:"" counter(lst-ctn-kix_guu3akn5m1j8-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Beat the eggs, milk, salt and pepper in a bowl until blended.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_guu3akn5m1j8-0} :before{content:"" counter(lst-ctn-kix_guu3akn5m1j8-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Heat the butter in a large nonstick skillet over medium heat until hot. </span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_guu3akn5m1j8-0} :before{content:"" counter(lst-ctn-kix_guu3akn5m1j8-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Pour in the egg mixture.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_guu3akn5m1j8-0} :before{content:"" counter(lst-ctn-kix_guu3akn5m1j8-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">As the eggs set, gently push the edges of the mixture toward the center of the pan, forming large soft curds. &nbsp;Continue this process until no visible liquid remains.</span></li><li align="left" style='{color:#000; font-family:"Cambria"; font-size:12pt; line-height:1.15; margin-left:36pt; padding-bottom:0; padding-left:0; padding-top:0; text-align:left; counter-increment:lst-ctn-kix_guu3akn5m1j8-0} :before{content:"" counter(lst-ctn-kix_guu3akn5m1j8-0, decimal) ". "}; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Remove the eggs from heat and serve.</span></li></ol><br/></td></tr></tbody></table><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
