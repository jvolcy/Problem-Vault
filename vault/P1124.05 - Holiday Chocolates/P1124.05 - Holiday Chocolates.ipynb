# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo (no bg).png" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; page-break-after:avoid; font-weight:700; '><span>P1124.05 - Holiday Chocolates</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:9pt; font-weight:700; ' valign="baseline">JVolcy</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">The 3 lists below describe a box of assorted chocolates. &nbsp;There are 5 flavor choices:</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Caramel Delight, Rum Nougat, Dark Chocolate, Almond Truffle and Butterscotch Chew. &nbsp;Each flavor has a 2-letter designation. &nbsp;The flavor designations and their corresponding descriptions are stored in the global lists </span><span style='font-family:"Courier New"; font-weight:400; '>flavors</span><span>&nbsp;and </span><span style='font-family:"Courier New"; font-weight:400; '>descriptions</span><span>&nbsp;as shown below. &nbsp;Copy and paste these into your script or begin with the starter code found </span><span style="-webkit-text-decoration-skip:none; color:#15c; text-decoration:underline; text-decoration-skip-ink:none; "><a href="https://www.google.com/url?q=https://drive.google.com/open?id%3D1ynORW5wlDnbRxUK_x0VUWyT8ncdhxz7M&amp;sa=D&amp;ust=1577371889020000" style="color:inherit; text-decoration:inherit; ">here</a></span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">.</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">flavors = ['CD', 'RN', 'DC', 'AT', 'BC']</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">descriptions = ['Caramel Delight', 'Rum Nougat', </span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">'Dark Chocolate', 'Almond Truffle', 'Butterscotch Chew']</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">box = [</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; ['XX', 'XX', 'XX', 'XX', 'XX', 'XX'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; ['XX', 'XX', 'XX', 'XX', 'XX', 'XX'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; ['XX', 'XX', 'XX', 'XX', 'XX', 'XX'],</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; &nbsp; ['XX', 'XX', 'XX', 'XX', 'XX', 'XX']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; &nbsp; ]</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Holiday chocolates are packed into a 6x4 box represented by the </span><span style='font-family:"Courier New"; font-weight:400; '>box</span><span>&nbsp;nested list above. &nbsp;When a piece of chocolate is missing, its place in the box is marked with a ‘XX’. &nbsp;Otherwise, the flavor code is used. &nbsp;Initially, the box is empty as shown above.</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:700; ' valign="baseline">Part A</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Write </span><span style="-webkit-text-decoration-skip:none; text-decoration:underline; text-decoration-skip-ink:none; ">a function</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;that neatly prints out the contents of the box. &nbsp;Call this function to print out the initial contents of the box. &nbsp;Your output should look something &nbsp;like this:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">+-------------------+</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">+-------------------+</span></p><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:700; ' valign="baseline">Part B</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Randomly fill the box with chocolates from the </span><span style='font-family:"Courier New"; font-weight:400; '>flavors</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;list. &nbsp;Use the function you wrote in Part A to print out the contents of the full box. &nbsp;Your output might look something like this:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| RN CD RN CD DC DC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| RN CD DC AT RN RN |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| AT BC CD CD DC DC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| DC CD DC AT AT BC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-size:10pt; font-weight:400; '>+-------------------+</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:700; ' valign="baseline">Part C</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Prompt the user for the row (1 to 4) and column (1 to 6) coordinates of her choice of chocolate. &nbsp;Update and print the box to reflect the eaten morsel (should now be marked with ‘XX’). &nbsp;You must do input validation and re-prompt the user if her input is out of range. &nbsp;Finally, you should print the description of her choice. &nbsp;Here is a sample session:</span></p><br/><br/><a id="t.dd733cd6bb2af3e1c01ac21549dd1eb3a616ba5a"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:468pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="468pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">Empty box</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| XX XX XX XX XX XX |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">Filled box</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| RN CD RN CD DC DC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| RN CD DC AT RN RN |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| AT BC CD CD DC DC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| DC CD DC AT AT BC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-size:10pt; font-weight:400; '>Enter the row (1-4) of your choice: </span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:700; ' valign="baseline">6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">That is not a valid choice.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-size:10pt; font-weight:400; '>Enter the row (1-4) of your choice: </span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:700; ' valign="baseline">2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-size:10pt; font-weight:400; '>Enter the column (1-6) of your choice: </span><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:700; ' valign="baseline">5</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">You have selected a piece of Rum Nougat.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| RN CD RN CD DC DC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| RN CD DC AT XX RN |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| AT BC CD CD DC DC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">| DC CD DC AT AT BC |</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Courier New"; font-size:10pt; font-weight:400; ' valign="baseline">+-------------------+</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Cambria"; font-size:12pt; font-weight:700; ' valign="baseline">Part D</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Print out a table with the description and number of pieces left in the box. &nbsp;Here is a sample output:</span></p><br/><br/><a id="t.20522bc2411e8f689a956caf2af38823c64f0d93"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#cfe2f3; vertical-align:top; width:468pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="468pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Remaining Inventory</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">-------------------</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Caramel Delight&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;6</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Rum Nougat&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Dark Chocolate&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;7</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Almond Truffle&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Butterscotch Chew&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Total&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;23</span></p></td></tr></tbody></table><br/><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
