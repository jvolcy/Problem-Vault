# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:432pt; padding:72pt 90pt 72pt 90pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="font-size:16pt; font-weight:700; ">P0004</span><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo (no bg).png" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-style:normal; text-decoration:none; vertical-align:baseline; font-size:16pt; font-weight:700; ' valign="baseline">Mutables &amp; Immutables</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-style:normal; text-decoration:none; vertical-align:baseline; font-size:9pt; font-weight:700; ' valign="baseline">J. Volcy</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">For each segment of code below, predict the output. &nbsp;Then, verify your prediction using the Python console or by writing a short script.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">def myFunc(x):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; x = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; x[1] = 'w'</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">def main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; myList = ['s', 'c', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; myFunc(myList)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; print(myList)</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>2)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = x</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = 500</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(y)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x[1] = 'w'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(y)</span></p><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x == y)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x is y)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x[1] = 'w'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x == y)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x is y)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>5)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = x</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x[1] = 'w'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(y == x)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(y is x)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">def myFunc(x):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; x[1] = 'w'</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">def main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; myVar = 's', 'c', 'a', 'm'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; myFunc(myVar)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; print(myVar)</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = ['s', 'p', 'a', 'm']</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = x[:]</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x == y)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x is y)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y[1] = 'c'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Courier New"; font-weight:400; '>print(y)</span></p><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = 'green eggs and ham'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = tuple(x)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(y)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">9)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = 'green eggs and ham'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">w = x.split()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = tuple(w[::-1])</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(y)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>10)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = [1.23, 4.56, 7.89]</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = x</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x[1] = 8</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = [1, 2, 3]</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x[0] = 10</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = y</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print(x)</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">11)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">def myFunc(x):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; y = list(x)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; y[2] = 123</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; return tuple(y)</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">def main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; w = 'a', 'b', 'c', 456</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; z = myFunc(w)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; print(z)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; v = str(w)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp; &nbsp; print(v)</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">12)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x = 'abc'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">y = x</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print (y is x)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">x += 'xyz'</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-left:36pt; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">print (y is x)</span></p><br/><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-style:normal; text-decoration:none; vertical-align:baseline; font-size:10pt; font-weight:400; ' valign="baseline">JVolcy – Spelman College – Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
