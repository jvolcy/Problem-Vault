# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span>P1220</span><span>&nbsp;- Credit Card Checker</span></p><br/><br/><br/><h1 align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:700; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1 The Luhn Algorithm</span><span style="overflow:hidden; display:inline-block; margin:0.00px 0.00px; border:0.00px solid #000000; width:295.50px; height:258.51px; "><img align="right" alt="62858-53327.jpg" src="images/image2.jpg" style="width:331.98px; height:296.10px; margin:10px; "/></span></h1><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">The Luhn Algorithm is a method of &nbsp;detecting errors when humans enter long numeric sequences like credit card numbers. &nbsp;To be effective, the credit card company has to issue credit card numbers based on the Luhn Algorithm (and most do). &nbsp;Luhn numbers have a mathematical property that makes it possible to reconstruct a number even if one of its digits is missing. &nbsp;It can therefore be used as a simple way to detect an error in user entered numeric data. &nbsp;The following example shows how the algorithm works.</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Assume we’ve written a program that asks the user to enter a credit card number. &nbsp;Now, we wish to check if the number entered is a valid card number. &nbsp;Assume the user has entered the following 16-digit number:</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; margin-left:72pt; text-indent:36pt; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5424 9183 1627 7235</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span>We begin by covering up the last digit (in this case, 5) &nbsp;of the user entered number. &nbsp;This digit is called the </span><span style="font-style:italic; ">check digit</span><span>&nbsp;and is shown as a </span><span>'</span><span>?</span><span>'</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;in the gray boxes below. &nbsp;Now, using only the remaining digits, we will attempt to recover the value of the check digit. &nbsp;If we are successful, then we know that the credit card number entered by the user is valid.</span></p><br/><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step 1: cover the check digit; we will not use it in our calculations</span></p><a id="t.51e1f9be04f301d8d012f21e66a14b93f52f2f0d"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:auto; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:middle; width:29.2pt; border-color:#000; border-style:solid; " valign="middle" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:0; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">⬇</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">8</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td bgcolor="#cccccc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#ccc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">?</span></p></td></tr></tbody></table><br/><br/><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step 2: starting from the right, double every other value after the check digit</span></p><br/><a id="t.cf12d03ba4e642df7ef56349724381d3ae74e059"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:auto; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">10</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">18</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">16</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">14</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#cccccc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#ccc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">?</span></p></td></tr></tbody></table><hr style="page-break-before:always; display:none; "/><br/><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step 3: if any of the doubled values from step 2 yielded a result greater than 9, subtract 9 from that result</span></p><br/><a id="t.00d937a2390238b702e19d227e6183c2c49057a6"></a><a id="t.2"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:auto; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#f00; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">10</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#f00; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">18</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#f00; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">16</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#f00; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">14</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td bgcolor="#fff2cc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#fff2cc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#cccccc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#ccc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">?</span></p></td></tr><tr height="0" style="height:0; "><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:0; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:middle; width:29.2pt; border-color:#000; border-style:solid; " valign="middle" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">⬇</span></p></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">⬇</span></p></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">⬇</span></p></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">⬇</span></p></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td><td bgcolor="#ffffff" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; background-color:#fff; border-bottom-width:1pt; border-left-width:0; border-right-width:0; border-top-width:1pt; vertical-align:top; width:29.2pt; border-color:#000; border-style:solid; " valign="top" width="29.2pt"><br/></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0; vertical-align:middle; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="middle" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td bgcolor="#cccccc" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:29.2pt; background-color:#ccc; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="29.2pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">?</span></p></td></tr></tbody></table><br/><br/><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step 4: Calculate the sum of the non-check digits.</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style="font-style:italic; ">Non-Check Sum</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;= 1 + 4 + 4 + 4 + 9 + 1 + 7 + 3 + 2 + 6 + 4 + 7 + 5 + 2 + 6 = 65</span></p><br/><br/><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Step 5: Calculate the check digit. &nbsp;The check digit is calculated using the formula </span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style="font-style:italic; ">Check Digit</span><span>&nbsp;= (9 * </span><span style="font-style:italic; ">Non-Check Sum</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">) % 10.</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">For our example, </span></p><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style="font-style:italic; ">Check Digit</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;= (9 * 65) % 10 = 5</span></p><br/><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Because this value matches the check digit entered by the user, we know this is a valid CC number.</span></p><br/><br/><br/><h1 align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:700; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:justify; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">2 Assignment</span></h1><p align="justify" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:justify; '><span>Write a program that accepts a credit card number from the user and confirms whether or not the number entered is a valid card number. &nbsp;Note that your program should allow the user to enter the card number with arbitrarily inserted spaces, as in the example</span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">. &nbsp;Validate the user’s input which should consist of only numeric characters and spaces. &nbsp;Re-prompt the user until the input is valid. &nbsp;Test your algorithm against your own credit card.</span></p><br/><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
