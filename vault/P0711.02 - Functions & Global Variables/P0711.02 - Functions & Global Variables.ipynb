# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">P0711.02</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Functions &amp; Global Variables</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:10pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">JVolcy</span></p><br/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">For each program, identify the order of execution. &nbsp;Then, predict the output.</span></p><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Roboto Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 1</span></p><br/><a id="t.d40081ca91304208a3717f086d2194f36f4b82bb"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:90.9pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="90.9pt"><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:405.9pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="405.9pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#Program that demonstrates use of global variables.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the accolades function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;accolades():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the main function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accolades()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#call main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 2</span></p><br/><br/><a id="t.b986d626236e175af9a1e340de31cc203d1d9c89"></a><a id="t.1"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#Program that demonstrates use of global variables.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the accolades function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;accolades():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">10</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the main function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accolades()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#call main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/><br/></td></tr></tbody></table><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 3</span></p><br/><br/><a id="t.ce0b6abe62a5f1b1e8a97b3d472000846f5d31a2"></a><a id="t.2"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#Program that demonstrates use of global variables.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the accolades function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;accolades():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>global</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;kudos</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">10</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the main function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accolades()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#call main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 4</span></p><br/><br/><br/><a id="t.11697048e41a9d571ce6247523e446687148318c"></a><a id="t.3"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#Program that demonstrates use of global variables.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the props function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;props(kudos):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kudos += </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the accolades function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;accolades():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>global</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;kudos</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;props(kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the main function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accolades()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#call main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><br/></td></tr></tbody></table><br/><hr style="page-break-before:always; display:none; "/><br/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 5</span></p><br/><br/><a id="t.a7dbf30e6896a37557142a1b4ce58590d1d872bf"></a><a id="t.4"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#Program that demonstrates use of global variables.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the props function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;props(kudos):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kudos += </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the accolades function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;accolades():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>global</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;kudos</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;props(kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the main function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accolades()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#call main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p><br/></td></tr></tbody></table><hr style="page-break-before:always; display:none; "/><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Program 6</span></p><br/><br/><a id="t.a7d5f867219a928c10c0ae4774d3ae18eaf3042d"></a><a id="t.5"></a><table style="border-collapse:collapse; border-spacing:0; margin-left:-5.4pt; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><p align="right" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:right; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">_________</span></p><br/><br/><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#Program that demonstrates use of global variables.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>kudos = </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">3</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the props function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;props(kudos):</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kudos += </span><span style='color:#1c00cf; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the accolades function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;accolades():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>global</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;kudos</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;props(kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kudos += </span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#1c00cf; '>1</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#definition of the main function</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>def</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;main():</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accolades()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='font-family:"Droid Sans Mono"; font-weight:400; '>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span><span style='color:#9b2393; font-family:"Droid Sans Mono"; font-weight:400; '>print</span><span style='font-family:"Droid Sans Mono"; font-weight:400; '>(</span><span style='font-family:"Droid Sans Mono"; font-weight:400; color:#d20000; '>"My kudos:"</span><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">, kudos)</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#009600; font-size:12pt; font-style:normal; text-decoration:none; vertical-align:baseline; font-family:"Droid Sans Mono"; font-weight:400; ' valign="baseline">#call main()</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1.5; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Droid Sans Mono"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">main()</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:86.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="86.4pt"><br/></td><td colspan="1" rowspan="1" style="padding:0 5.4pt 0 5.4pt; vertical-align:top; width:410.4pt; border-color:#000; border-width:0; border-style:solid; " valign="top" width="410.4pt"><br/></td></tr></tbody></table><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='font-family:"Cambria"; font-weight:400; color:#999; font-size:10pt; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='font-family:"Cambria"; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; color:#999; font-size:10pt; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
