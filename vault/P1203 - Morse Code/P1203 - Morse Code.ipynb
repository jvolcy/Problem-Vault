# %% [markdown]
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/></head><body bgcolor="#ffffff" style="background-color:#fff; max-width:468pt; padding:54pt 72pt 54pt 72pt; "><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:right; '><span style="overflow:hidden; display:inline; margin:0.00px 0.00px; border:0.00px solid #000000; width:243.33px; "><img align="right" alt="CS Logo" src="../../images/cs_logo.png" style="width:243.33px; margin:10px; "/><br/><br/></span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">P1203/P1301</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:16pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; font-weight:700; '><span style='color:#000; font-family:"Cambria"; font-size:16pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">Morse Code</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:9pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">(Gaddis, Python, 3e)</span></p><br/><br/><h1 align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:700; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; '><span>P1203 (String Exercise)</span></h1><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Morse code is a code where each letter of the English alphabet, each digit, and various punctuation characters are represented by a series of dots and dashes. The table below shows part of the code.</span></p><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Write a program that asks the user to enter a string, and then converts that string to Morse code. &nbsp;You may use the skeleton code file </span><span style='-webkit-text-decoration-skip:none; color:#15c; font-family:"Courier New"; font-weight:400; text-decoration:underline; text-decoration-skip-ink:none; '><a href="https://www.google.com/url?q=https://drive.google.com/open?id%3D0B_r-sqlBQ5V3UmJJaXB1WElBaDA&amp;sa=D&amp;ust=1577371856145000" style="color:inherit; text-decoration:inherit; ">P1203.py</a></span><span style='color:#000; font-family:"Cambria"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">&nbsp;as a starting point.</span></p><br/><br/><a id="t.1b829831847a8dc8c24f90908caac4d135cc14d2"></a><a id="t.0"></a><table style="border-collapse:collapse; border-spacing:0; margin-right:auto; "><tbody><tr height="0" style="height:0; "><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Char</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Code</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Char</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Code</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Char</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Code</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Char</span></p></td><td bgcolor="#cfe2f3" colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; background-color:#cfe2f3; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:12pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Code</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">A</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">K</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-.-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">U</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">..-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">4</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">....-</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">B</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-...</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">L</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.-..</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">V</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">...-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">5</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.....</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">C</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-.-.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">M</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">--</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">W</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.--</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">6</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-....</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">D</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-..</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">N</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">X</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-..-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">7</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">--...</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">E</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">O</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">---</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Y</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-.-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">8</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">---..</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">F</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">..-.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">P</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.--.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Z</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">--..</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">9</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">----.</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">G</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">--.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">Q</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">--.-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">0</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-----</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">(space)</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">space</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">H</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">....</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">R</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.-.</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">1</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.----</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">(comma)</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">--..--</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">I</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">..</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">S</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">...</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">2</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">..---</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">(period)</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.-.-.-</span></p></td></tr><tr height="0" style="height:0; "><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">J</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">.---</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">T</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">-</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">3</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">...--</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Arial"; font-size:10pt; font-style:normal; font-weight:400; text-decoration:none; vertical-align:baseline; ' valign="baseline">?</span></p></td><td colspan="1" rowspan="1" style="padding:5pt 5pt 5pt 5pt; vertical-align:top; width:58.5pt; border-color:#000; border-width:1pt; border-style:solid; " valign="top" width="58.5pt"><p align="center" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:center; '><span style='color:#000; font-family:"Courier New"; font-size:12pt; font-style:normal; font-weight:700; text-decoration:none; vertical-align:baseline; ' valign="baseline">..--..</span></p></td></tr></tbody></table><br/><br/><br/><h1 align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; font-weight:700; line-height:1; padding-bottom:0; padding-top:0; page-break-after:avoid; text-align:left; '><span>P1301 (Dictionary Exercise)</span></h1><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; padding-bottom:0; padding-top:0; text-align:left; '><span>Repeat problem P1203. &nbsp;This time, solve the problem using a dictionary. &nbsp;You may use the skeleton code file </span><span style='-webkit-text-decoration-skip:none; color:#15c; font-family:"Courier New"; font-weight:400; text-decoration:underline; text-decoration-skip-ink:none; '><a href="https://www.google.com/url?q=https://drive.google.com/open?id%3D0B_r-sqlBQ5V3cFJ5Q3U5Ykx2Zlk&amp;sa=D&amp;ust=1577371856177000" style="color:inherit; text-decoration:inherit; ">P1301.py</a></span><span>&nbsp;as a starting point.</span></p><br/><br/><br/><div><br/><p align="left" style='color:#000; font-family:"Cambria"; font-size:12pt; margin:0; line-height:1; margin-right:18pt; padding-bottom:36pt; padding-top:0; text-align:left; '><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; '>Spelman College </span><span style="color:#999; font-size:10pt; ">&nbsp; </span><span style='color:#999; font-family:"Cambria"; font-size:10pt; font-weight:400; font-style:normal; text-decoration:none; vertical-align:baseline; ' valign="baseline">– &nbsp; Computer and Information Sciences</span></p></div></body></html>

# %%
# Add your code here
