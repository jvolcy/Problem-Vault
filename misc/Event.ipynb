# %%
import ipywidgets as widgets

button = widgets.Button(description="Click Me!")
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
    with output:
        print("Button clicked.")

button.on_click(on_button_clicked)
# Out:
# Button(description='Click Me!', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets

button2 = widgets.Button(description="Button 2")
display(button2)

def on_button2_clicked(b):
    print("Button2 clicked.")
    print(b)

button2.on_click(on_button2_clicked)
# Out:
# Button(description='Button 2', style=ButtonStyle())

# %% [markdown]
# <html><head>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@*/dist/embed-amd.js" crossorigin="anonymous"></script>
# <script type="application/vnd.jupyter.widget-state+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "state": {
#         "08b97ff2f74641f291edf03278c39a36": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "2ab7883164dd400ebed5d2ccea7e2752": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "2b31373cc1c14e83a958ed6b6d815f96": {
#             "model_name": "OutputModel",
#             "model_module": "@jupyter-widgets/output",
#             "model_module_version": "1.0.0",
#             "state": {
#                 "layout": "IPY_MODEL_f5be3aafde9246df9b4a0ef9158dcef4",
#                 "outputs": [
#                     {
#                         "name": "stdout",
#                         "output_type": "stream",
#                         "text": "Button clicked.\nButton clicked.\nButton clicked.\n"
#                     }
#                 ]
#             }
#         },
#         "44933205449f4b54812ce455eb950e5c": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "60f67f61df6d4d4183ba88e830cfc0a6": {
#             "model_name": "OutputModel",
#             "model_module": "@jupyter-widgets/output",
#             "model_module_version": "1.0.0",
#             "state": {
#                 "layout": "IPY_MODEL_44933205449f4b54812ce455eb950e5c"
#             }
#         },
#         "7d1a4831de82403492ecd021bea4aa58": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "99eb13d3603d439b976fcaf4e7132f53": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "9a5107ed1c5441d4be4cbed454d41b9f": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "aeaa8f93b16a430aa316c4c81551bcae": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "c7ee71a3b1be47d0bc068d6381fb7dcc": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Click Me!",
#                 "layout": "IPY_MODEL_9a5107ed1c5441d4be4cbed454d41b9f",
#                 "style": "IPY_MODEL_e462dbb27f464871aceb7600f6d14747"
#             }
#         },
#         "dd0e075f1df749e6b2ddf712abbcabc4": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Click Me!",
#                 "layout": "IPY_MODEL_08b97ff2f74641f291edf03278c39a36",
#                 "style": "IPY_MODEL_7d1a4831de82403492ecd021bea4aa58"
#             }
#         },
#         "df43845900f24797b3ac3462621716d1": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "e462dbb27f464871aceb7600f6d14747": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "ef49cc96b22a4f578c0e18d9871bd832": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Button 2",
#                 "layout": "IPY_MODEL_99eb13d3603d439b976fcaf4e7132f53",
#                 "style": "IPY_MODEL_2ab7883164dd400ebed5d2ccea7e2752"
#             }
#         },
#         "f5be3aafde9246df9b4a0ef9158dcef4": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "f726c421c9d948848c15e292ab87ba1e": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Button 3",
#                 "layout": "IPY_MODEL_df43845900f24797b3ac3462621716d1",
#                 "style": "IPY_MODEL_aeaa8f93b16a430aa316c4c81551bcae"
#             }
#         },
#         "4866c200146a4f5eb5c1c4b297bbb6ce": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "a65f1d1196624f7ba4596350b0e30003": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "f5225c20d1a64095abc1c50239902a0b": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Click Me!",
#                 "layout": "IPY_MODEL_4866c200146a4f5eb5c1c4b297bbb6ce",
#                 "style": "IPY_MODEL_a65f1d1196624f7ba4596350b0e30003"
#             }
#         },
#         "689279dfbb5c45b386ea97ef0bb9d350": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "3459eb4094024b138ca71dc4d071fd86": {
#             "model_name": "OutputModel",
#             "model_module": "@jupyter-widgets/output",
#             "model_module_version": "1.0.0",
#             "state": {
#                 "layout": "IPY_MODEL_689279dfbb5c45b386ea97ef0bb9d350"
#             }
#         },
#         "f3e00643500442db8578b91fd7b48353": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "80fe41273fa54c15a3e216d0c87d5463": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "768c839577b84bd3832493ef8027ffb0": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Button 2",
#                 "layout": "IPY_MODEL_f3e00643500442db8578b91fd7b48353",
#                 "style": "IPY_MODEL_80fe41273fa54c15a3e216d0c87d5463"
#             }
#         },
#         "1764fb95d846497784c3ec0916284eec": {
#             "model_name": "LayoutModel",
#             "model_module": "@jupyter-widgets/base",
#             "model_module_version": "1.1.0",
#             "state": {}
#         },
#         "72a51300696f4c868c2c72477894d31b": {
#             "model_name": "ButtonStyleModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {}
#         },
#         "02f745c8d73946ea83e3a7d25352ddb0": {
#             "model_name": "ButtonModel",
#             "model_module": "@jupyter-widgets/controls",
#             "model_module_version": "1.4.0",
#             "state": {
#                 "description": "Button 3",
#                 "layout": "IPY_MODEL_1764fb95d846497784c3ec0916284eec",
#                 "style": "IPY_MODEL_72a51300696f4c868c2c72477894d31b"
#             }
#         }
#     }
# }
# </script>
# </head>
# <body>
#
# <script type="application/vnd.jupyter.widget-view+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "model_id": "f5225c20d1a64095abc1c50239902a0b"
# }
# </script>
#
# <script type="application/vnd.jupyter.widget-view+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "model_id": "3459eb4094024b138ca71dc4d071fd86"
# }
# </script>
#
# <script type="application/vnd.jupyter.widget-view+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "model_id": "768c839577b84bd3832493ef8027ffb0"
# }
# </script>
#
# <script type="application/vnd.jupyter.widget-view+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "model_id": "02f745c8d73946ea83e3a7d25352ddb0"
# }
# </script>
#
# </body>
# </html>

# %%
import ipywidgets as widgets

button3 = widgets.Button(description="Button 3")
display(button3)

def on_button3_clicked(b):
    print("Button3 clicked.")
    print(b)

button3.on_click(on_button3_clicked)
# Out:
# Button(description='Button 3', style=ButtonStyle())
